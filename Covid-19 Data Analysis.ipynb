# %% [markdown]
# # Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset

# %%
corona_dataset = pd.read_csv('Datasets/covid19_Confirmed_dataset.csv')
corona_dataset.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# #### Checking DataFrame

# %%
corona_dataset.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Deleting Unnecessary Columns

# %%
corona_dataset.drop(['Lat','Long'], axis=1, inplace=True)

# %%
corona_dataset.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ### Task 2.3: Aggregating rows by country

# %%
corona_dataset_aggreageted = corona_dataset.groupby('Country/Region').sum()

# %%
corona_dataset_aggreageted.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggreageted.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing Country-Specific Data

# %%
corona_dataset_aggreageted.loc['China'].plot() 
corona_dataset_aggreageted.loc['Italy'].plot() 
corona_dataset_aggreageted.loc['Spain'].plot()

plt.legend()

# %% [markdown]
# ### Task3: Calculating an Appropriate Measure

# %%
corona_dataset_aggreageted.loc['China'].plot()

# %%
corona_dataset_aggreageted.loc['China'][:3].plot()

# %% [markdown]
# ### task 3.1: Calculating the First Derivative of the Curve

# %%
corona_dataset_aggreageted.loc['China'].diff().plot()

# %% [markdown]
# ### task 3.2: Identifying the Maximum Infection Rate for China, Italy, and Spain

# %%
corona_dataset_aggreageted.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggreageted.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggreageted.loc['Spain'].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Task 3.3: Identifying the Maximum Infection Rate for All Countries

# %%
countries = list(corona_dataset_aggreageted.index)
max_infection_rates = []

for c in countries :
    max_infection_rates.append(corona_dataset_aggreageted.loc[c].diff().max()) 
    

corona_dataset_aggreageted['max_infection_rate'] = max_infection_rates

# %%
corona_dataset_aggreageted.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ### Task 3.4: Creating a New DataFrame with Only the Necessary Column

# %%
corona_data = pd.DataFrame(corona_dataset_aggreageted['max_infection_rate'])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting the necessary columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happiness_report = pd.read_csv('Datasets/worldwide_happiness_report.csv')

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Task 4.2: Deleting Unnecessary Columns

# %%
drop_useless_columns = ['Overall rank', 'Score','Generosity','Perceptions of corruption']

# %%
happiness_report.drop(drop_useless_columns, axis=1,inplace=True)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
happiness_report.set_index('Country or region',inplace=True)

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### Task4.4: Joining the Datasets we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report,how='inner') 

data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Task 4.5: Generating the Correlation Matrix

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %% [markdown]
# ### Task 5: Visualization of the results
# To wrap up our analysis, we'll use figures and graphs to visualize the results. This will make it easier for everyone to understand our findings.

# %%
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Task 5.1: Plotting GDP per Capita vs. Maximum Infection Rate

# %%
x = data['GDP per capita']
y = data['max_infection_rate']


sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# In this plot, by fitting a line, it clearly shows a positive slope between these two variables, making the positive correlation easier to understand.

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max_infection_rate'] 

sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x, np.log(y))

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max_infection_rate']

sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x, np.log(y))

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max_infection_rate']

sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x, np.log(y))

# %% [markdown]
# # Executive Summary Report for COVID-19 Analysis
# ---
# ### Objective
# The objective of this analysis was to investigate the correlation between the maximum infection rate of the coronavirus and various life factors, such as GDP per capita, social support, healthy life expectancy, and freedom to make life choices.
#
# ### Key Findings
# After reviewing the plots, there appears to be a clear positive correlation between the maximum infection rate and the selected life‑quality factors. This suggests that people in more developed countries tended to show higher infection rates, possibly due to greater mobility or wider testing availability.
#
# ### Next Steps
# Since limited testing in less developed countries may have affected reported infection numbers, repeating the analysis using total deaths would help confirm the observed trends. Additionally, incorporating testing‑rate or mobility data could provide a clearer picture of how reporting differences and movement patterns influenced infection rates.
